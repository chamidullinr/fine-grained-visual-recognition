# %% [markdown]
# # 04 - Training Results - Training on Cropped Images (SnakeCLEF-Reduced)

# %%
import os

os.chdir('..')

# %%
import numpy as np
import pandas as pd

from src.utils import visualization as viz
from src.dev import results

DATA_DIR = 'data/snake_clef2021_dataset/training_history/image_cropping_mini/'


# load specification and progress data
specs_df = results.load_specs_files(DATA_DIR)
specs_df['note'] = specs_df['note'].fillna('')
df = results.load_progress_files(specs_df, path=DATA_DIR)
specs_df['history_file_full'] = specs_df['model_name'] + '_full.csv'
df_full = results.load_progress_files(specs_df, path=DATA_DIR, history_file_col='history_file_full')
specs_df
# Out:
#                                          model_name  \
# 0   clef2021_efficientnet_b0_ce_11-10-2021_11-09-53
# 1   clef2021_efficientnet_b0_ce_11-25-2021_19-15-29
# 2   clef2021_efficientnet_b0_ce_11-25-2021_21-43-54
# 3   clef2021_efficientnet_b0_ce_11-26-2021_00-16-24
# 4   clef2021_efficientnet_b0_ce_11-26-2021_02-49-41
# 5   clef2021_efficientnet_b0_ce_11-26-2021_06-49-49
# 6   clef2021_efficientnet_b0_ce_11-26-2021_09-26-31
# 7   clef2021_efficientnet_b0_ce_11-26-2021_12-02-56
# 8   clef2021_efficientnet_b0_ce_11-26-2021_14-37-21
# 9   clef2021_efficientnet_b0_ce_11-26-2021_17-20-53
# 10  clef2021_efficientnet_b0_ce_11-26-2021_20-05-25
# 11  clef2021_efficientnet_b0_ce_11-26-2021_22-48-41
# 12  clef2021_efficientnet_b0_ce_11-27-2021_01-41-57
# 13  clef2021_efficientnet_b0_ce_11-27-2021_04-35-09
#
#                                          history_file  \
# 0   clef2021_efficientnet_b0_ce_11-10-2021_11-09-5...
# 1   clef2021_efficientnet_b0_ce_11-25-2021_19-15-2...
# 2   clef2021_efficientnet_b0_ce_11-25-2021_21-43-5...
# 3   clef2021_efficientnet_b0_ce_11-26-2021_00-16-2...
# 4   clef2021_efficientnet_b0_ce_11-26-2021_02-49-4...
# 5   clef2021_efficientnet_b0_ce_11-26-2021_06-49-4...
# 6   clef2021_efficientnet_b0_ce_11-26-2021_09-26-3...
# 7   clef2021_efficientnet_b0_ce_11-26-2021_12-02-5...
# 8   clef2021_efficientnet_b0_ce_11-26-2021_14-37-2...
# 9   clef2021_efficientnet_b0_ce_11-26-2021_17-20-5...
# 10  clef2021_efficientnet_b0_ce_11-26-2021_20-05-2...
# 11  clef2021_efficientnet_b0_ce_11-26-2021_22-48-4...
# 12  clef2021_efficientnet_b0_ce_11-27-2021_01-41-5...
# 13  clef2021_efficientnet_b0_ce_11-27-2021_04-35-0...
#
#                                            specs_name            model loss  \
# 0   clef2021_efficientnet_b0_ce_11-10-2021_11-09-5...  efficientnet_b0   ce
# 1   clef2021_efficientnet_b0_ce_11-25-2021_19-15-2...  efficientnet_b0   ce
# 2   clef2021_efficientnet_b0_ce_11-25-2021_21-43-5...  efficientnet_b0   ce
# 3   clef2021_efficientnet_b0_ce_11-26-2021_00-16-2...  efficientnet_b0   ce
# 4   clef2021_efficientnet_b0_ce_11-26-2021_02-49-4...  efficientnet_b0   ce
# 5   clef2021_efficientnet_b0_ce_11-26-2021_06-49-4...  efficientnet_b0   ce
# 6   clef2021_efficientnet_b0_ce_11-26-2021_09-26-3...  efficientnet_b0   ce
# 7   clef2021_efficientnet_b0_ce_11-26-2021_12-02-5...  efficientnet_b0   ce
# 8   clef2021_efficientnet_b0_ce_11-26-2021_14-37-2...  efficientnet_b0   ce
# 9   clef2021_efficientnet_b0_ce_11-26-2021_17-20-5...  efficientnet_b0   ce
# 10  clef2021_efficientnet_b0_ce_11-26-2021_20-05-2...  efficientnet_b0   ce
# 11  clef2021_efficientnet_b0_ce_11-26-2021_22-48-4...  efficientnet_b0   ce
# 12  clef2021_efficientnet_b0_ce_11-27-2021_01-41-5...  efficientnet_b0   ce
# 13  clef2021_efficientnet_b0_ce_11-27-2021_04-35-0...  efficientnet_b0   ce
#
#     opt  no_epochs  batch_size  total_batch_size  learning_rate  ...  \
# 0   sgd         30          64                64           0.01  ...
# 1   sgd         30          64                64           0.01  ...
# 2   sgd         15          64                64           0.01  ...
# 3   sgd         30          64                64           0.01  ...
# 4   sgd         30          64                64           0.01  ...
# 5   sgd         30          64                64           0.01  ...
# 6   sgd         30          64                64           0.01  ...
# 7   sgd         30          64                64           0.01  ...
# 8   sgd         30          64                64           0.01  ...
# 9   sgd         30          64                64           0.01  ...
# 10  sgd         30          64                64           0.01  ...
# 11  sgd         30          64                64           0.01  ...
# 12  sgd         30          64                64           0.01  ...
# 13  sgd         30          64                64           0.01  ...
#
#                scheduler                                   note alpha mixup_p  \
# 0   reduce_lr_on_plateau                                          NaN     NaN
# 1   reduce_lr_on_plateau                        trained on crop   NaN     NaN
# 2   reduce_lr_on_plateau               trained on full and crop   NaN     NaN
# 3   reduce_lr_on_plateau      trained on full and crop (random)   NaN     NaN
# 4   reduce_lr_on_plateau  trained on full and crop (6 channels)   NaN     NaN
# 5   reduce_lr_on_plateau       trained on full and crop (mixup)   0.2    0.25
# 6   reduce_lr_on_plateau       trained on full and crop (mixup)   0.5    0.25
# 7   reduce_lr_on_plateau       trained on full and crop (mixup)   0.8    0.25
# 8   reduce_lr_on_plateau       trained on full and crop (mixup)   0.2    0.50
# 9   reduce_lr_on_plateau       trained on full and crop (mixup)   0.5    0.50
# 10  reduce_lr_on_plateau       trained on full and crop (mixup)   0.8    0.50
# 11  reduce_lr_on_plateau       trained on full and crop (mixup)   0.2    0.75
# 12  reduce_lr_on_plateau       trained on full and crop (mixup)   0.5    0.75
# 13  reduce_lr_on_plateau       trained on full and crop (mixup)   0.8    0.75
#
#     pretrained_checkpoint  input_size             image_mean  \
# 0      tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 1      tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 2      tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 3      tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 4      tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 5      tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 6      tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 7      tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 8      tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 9      tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 10     tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 11     tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 12     tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 13     tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
#
#                 image_std              date  \
# 0   [0.229, 0.224, 0.225]  10-2021_11-09-53
# 1   [0.229, 0.224, 0.225]  25-2021_19-15-29
# 2   [0.229, 0.224, 0.225]  25-2021_21-43-54
# 3   [0.229, 0.224, 0.225]  26-2021_00-16-24
# 4   [0.229, 0.224, 0.225]  26-2021_02-49-41
# 5   [0.229, 0.224, 0.225]  26-2021_06-49-49
# 6   [0.229, 0.224, 0.225]  26-2021_09-26-31
# 7   [0.229, 0.224, 0.225]  26-2021_12-02-56
# 8   [0.229, 0.224, 0.225]  26-2021_14-37-21
# 9   [0.229, 0.224, 0.225]  26-2021_17-20-53
# 10  [0.229, 0.224, 0.225]  26-2021_20-05-25
# 11  [0.229, 0.224, 0.225]  26-2021_22-48-41
# 12  [0.229, 0.224, 0.225]  27-2021_01-41-57
# 13  [0.229, 0.224, 0.225]  27-2021_04-35-09
#
#                                     history_file_full
# 0   clef2021_efficientnet_b0_ce_11-10-2021_11-09-5...
# 1   clef2021_efficientnet_b0_ce_11-25-2021_19-15-2...
# 2   clef2021_efficientnet_b0_ce_11-25-2021_21-43-5...
# 3   clef2021_efficientnet_b0_ce_11-26-2021_00-16-2...
# 4   clef2021_efficientnet_b0_ce_11-26-2021_02-49-4...
# 5   clef2021_efficientnet_b0_ce_11-26-2021_06-49-4...
# 6   clef2021_efficientnet_b0_ce_11-26-2021_09-26-3...
# 7   clef2021_efficientnet_b0_ce_11-26-2021_12-02-5...
# 8   clef2021_efficientnet_b0_ce_11-26-2021_14-37-2...
# 9   clef2021_efficientnet_b0_ce_11-26-2021_17-20-5...
# 10  clef2021_efficientnet_b0_ce_11-26-2021_20-05-2...
# 11  clef2021_efficientnet_b0_ce_11-26-2021_22-48-4...
# 12  clef2021_efficientnet_b0_ce_11-27-2021_01-41-5...
# 13  clef2021_efficientnet_b0_ce_11-27-2021_04-35-0...
#
# [14 rows x 22 columns]

# %%
def _filter_items(df_crop, df_full, outlen, **kwargs):
    group_crop = results.filter_items(df_crop, outlen=outlen, **kwargs)
    group_full = results.filter_items(df_full, outlen=1, **kwargs)
    return group_crop, group_full


def expand_group_tuple(group_crop, group_full, inverse_order=False):
    if inverse_order:
        pref1 = '_full'
        pref2 = '_crop'
        group_crop, group_full = group_full, group_crop
    else:
        pref1 = '_crop'
        pref2 = '_full'
    o = results.get_metrics_and_time(group_crop)
    metrics = ['accuracy', 'top_3', 'f1_score']
    for met in metrics:
        o[f'{met}{pref1}'] = o.pop(met)
    o.update({f'{k}{pref2}': v for k, v in group_full[metrics].iloc[0].items()})
    return o


params = dict(loss='ce', opt='sgd', model='efficientnet_b0', total_batch_size=64)

g1_full = results.filter_items(df, outlen=30, note='', **params)
g1_tuple = pd.DataFrame([{'accuracy': 0.7098410035459641, 'top_3': 0.8505738361230792, 'f1_score': 0.5391226671641873}]), g1_full

g2_tuple = _filter_items(df, df_full, outlen=30, note='trained on crop', **params)
g3_tuple = _filter_items(df, df_full, outlen=15, note='trained on full and crop', **params)
g4_tuple = _filter_items(df, df_full, outlen=30, note='trained on full and crop (random)', **params)
g5 = results.filter_items(df, outlen=30, note='trained on full and crop (6 channels)', **params)
g5_tuple = g5, pd.DataFrame([{'accuracy': None, 'top_3': None, 'f1_score': None}])

g6_tuple = _filter_items(df, df_full, outlen=30, note='trained on full and crop (mixup)', alpha=0.2, mixup_p=0.25, **params)
g7_tuple = _filter_items(df, df_full, outlen=30, note='trained on full and crop (mixup)', alpha=0.5, mixup_p=0.25, **params)
g8_tuple = _filter_items(df, df_full, outlen=30, note='trained on full and crop (mixup)', alpha=0.8, mixup_p=0.25, **params)

g9_tuple = _filter_items(df, df_full, outlen=30, note='trained on full and crop (mixup)', alpha=0.2, mixup_p=0.5, **params)
g10_tuple = _filter_items(df, df_full, outlen=30, note='trained on full and crop (mixup)', alpha=0.5, mixup_p=0.5, **params)
g11_tuple = _filter_items(df, df_full, outlen=30, note='trained on full and crop (mixup)', alpha=0.8, mixup_p=0.5, **params)

g12_tuple = _filter_items(df, df_full, outlen=30, note='trained on full and crop (mixup)', alpha=0.2, mixup_p=0.75, **params)
g13_tuple = _filter_items(df, df_full, outlen=30, note='trained on full and crop (mixup)', alpha=0.5, mixup_p=0.75, **params)
g14_tuple = _filter_items(df, df_full, outlen=30, note='trained on full and crop (mixup)', alpha=0.8, mixup_p=0.75, **params)


group_dict = {
    'Trained on crop': g2_tuple,
    'Trained on full and crop': g3_tuple,
    'Trained on full and crop (random)': g4_tuple,
    'Trained on full and crop (6 channels)': g5_tuple,

    'Trained on full and crop (mixup: alpha=0.2, p=0.25)': g6_tuple,
    'Trained on full and crop (mixup: alpha=0.5, p=0.25)': g7_tuple,
    'Trained on full and crop (mixup: alpha=0.8, p=0.25)': g8_tuple,

    'Trained on full and crop (mixup: alpha=0.2, p=0.5)': g9_tuple,
    'Trained on full and crop (mixup: alpha=0.5, p=0.5)': g10_tuple,
    'Trained on full and crop (mixup: alpha=0.8, p=0.5)': g11_tuple,

    'Trained on full and crop (mixup: alpha=0.2, p=0.75)': g12_tuple,
    'Trained on full and crop (mixup: alpha=0.5, p=0.75)': g13_tuple,
    'Trained on full and crop (mixup: alpha=0.8, p=0.75)': g14_tuple,
}
_results = {'Trained on full': expand_group_tuple(*g1_tuple, inverse_order=True)}
for k, (group_crop, group_full) in group_dict.items():
    _results[k] = expand_group_tuple(group_crop, group_full)
result_df = pd.DataFrame.from_dict(_results, orient='index')
result_df = result_df[['accuracy_full', 'accuracy_crop', 'top_3_full', 'top_3_crop', 'f1_score_full', 'f1_score_crop',
                       'mean_epoch_time', 'total_time']]
viz.heatmap(result_df)

result_df.round(3) * ([100] * 6 + [1, 1])
# Out:
#                                                     accuracy_full  \
# Trained on full                                              69.1
# Trained on crop                                              61.3
# Trained on full and crop                                     58.7
# Trained on full and crop (random)                            69.0
# Trained on full and crop (6 channels)                         NaN
# Trained on full and crop (mixup: alpha=0.2, p=0...           60.4
# Trained on full and crop (mixup: alpha=0.5, p=0...           55.4
# Trained on full and crop (mixup: alpha=0.8, p=0...           58.6
# Trained on full and crop (mixup: alpha=0.2, p=0.5)           65.1
# Trained on full and crop (mixup: alpha=0.5, p=0.5)           58.4
# Trained on full and crop (mixup: alpha=0.8, p=0.5)           68.7
# Trained on full and crop (mixup: alpha=0.2, p=0...           65.0
# Trained on full and crop (mixup: alpha=0.5, p=0...           56.0
# Trained on full and crop (mixup: alpha=0.8, p=0...           61.8
#
#                                                     accuracy_crop  top_3_full  \
# Trained on full                                              71.0        80.7
# Trained on crop                                              68.9        87.8
# Trained on full and crop                                     61.6        81.5
# Trained on full and crop (random)                            67.2        85.0
# Trained on full and crop (6 channels)                        62.9         NaN
# Trained on full and crop (mixup: alpha=0.2, p=0...           67.6        81.1
# Trained on full and crop (mixup: alpha=0.5, p=0...           70.0        80.5
# Trained on full and crop (mixup: alpha=0.8, p=0...           63.1        78.5
# Trained on full and crop (mixup: alpha=0.2, p=0.5)           72.0        88.7
# Trained on full and crop (mixup: alpha=0.5, p=0.5)           65.5        83.1
# Trained on full and crop (mixup: alpha=0.8, p=0.5)           66.5        83.9
# Trained on full and crop (mixup: alpha=0.2, p=0...           67.3        82.6
# Trained on full and crop (mixup: alpha=0.5, p=0...           65.8        78.8
# Trained on full and crop (mixup: alpha=0.8, p=0...           62.0        83.6
#
#                                                     top_3_crop  f1_score_full  \
# Trained on full                                           85.1           57.5
# Trained on crop                                           81.8           53.7
# Trained on full and crop                                  83.1           57.3
# Trained on full and crop (random)                         86.0           59.3
# Trained on full and crop (6 channels)                     87.4            NaN
# Trained on full and crop (mixup: alpha=0.2, p=0...        85.4           58.0
# Trained on full and crop (mixup: alpha=0.5, p=0...        89.4           51.5
# Trained on full and crop (mixup: alpha=0.8, p=0...        80.3           54.7
# Trained on full and crop (mixup: alpha=0.2, p=0.5)        89.2           57.5
# Trained on full and crop (mixup: alpha=0.5, p=0.5)        89.5           54.0
# Trained on full and crop (mixup: alpha=0.8, p=0.5)        87.0           53.9
# Trained on full and crop (mixup: alpha=0.2, p=0...        84.6           56.2
# Trained on full and crop (mixup: alpha=0.5, p=0...        86.4           50.6
# Trained on full and crop (mixup: alpha=0.8, p=0...        86.1           51.8
#
#                                                     f1_score_crop  \
# Trained on full                                              53.9
# Trained on crop                                              60.1
# Trained on full and crop                                     58.0
# Trained on full and crop (random)                            59.2
# Trained on full and crop (6 channels)                        56.7
# Trained on full and crop (mixup: alpha=0.2, p=0...           60.3
# Trained on full and crop (mixup: alpha=0.5, p=0...           57.6
# Trained on full and crop (mixup: alpha=0.8, p=0...           59.4
# Trained on full and crop (mixup: alpha=0.2, p=0.5)           59.8
# Trained on full and crop (mixup: alpha=0.5, p=0.5)           56.7
# Trained on full and crop (mixup: alpha=0.8, p=0.5)           58.4
# Trained on full and crop (mixup: alpha=0.2, p=0...           56.4
# Trained on full and crop (mixup: alpha=0.5, p=0...           54.8
# Trained on full and crop (mixup: alpha=0.8, p=0...           58.0
#
#                                                    mean_epoch_time total_time
# Trained on full                                                06m     2h 49m
# Trained on crop                                                05m     2h 27m
# Trained on full and crop                                       11m     2h 31m
# Trained on full and crop (random)                              06m     2h 32m
# Trained on full and crop (6 channels)                          08m     4h 00m
# Trained on full and crop (mixup: alpha=0.2, p=0...             06m     2h 35m
# Trained on full and crop (mixup: alpha=0.5, p=0...             06m     2h 35m
# Trained on full and crop (mixup: alpha=0.8, p=0...             06m     2h 33m
# Trained on full and crop (mixup: alpha=0.2, p=0.5)             06m     2h 42m
# Trained on full and crop (mixup: alpha=0.5, p=0.5)             06m     2h 43m
# Trained on full and crop (mixup: alpha=0.8, p=0.5)             06m     2h 41m
# Trained on full and crop (mixup: alpha=0.2, p=0...             06m     2h 51m
# Trained on full and crop (mixup: alpha=0.5, p=0...             06m     2h 51m
# Trained on full and crop (mixup: alpha=0.8, p=0...             06m     2h 51m

# %%
results.compare_training_process({k: v[0] for k, v in group_dict.items()})
