# %% [markdown]
# # 01 - Training Results - Baseline Networks (SnakeCLEF)

# %%
import os

os.chdir('..')

# %%
from src.utils import visualization as viz
from src.dev import results

DATA_DIR = 'data/snake_clef2021_dataset/training_history/baselines/'


# load specification and progress data
specs_df = results.load_specs_files(DATA_DIR)
df = results.load_progress_files(specs_df, path=DATA_DIR)
specs_df
# Out:
#                                            model_name  \
# 0        clef2021_vit_base_224_ce_12-01-2021_09-37-32
# 1   clef2021_efficientnet_b4_ns_ce_12-01-2021_09-3...
# 2        clef2021_vit_base_384_ce_12-01-2021_09-37-35
# 3     clef2021_efficientnet_b4_ce_12-01-2021_21-42-26
# 4    clef2021_efficientnetv2_s_ce_12-02-2021_14-00-43
# 5       clef2021_deit_base_384_ce_12-02-2021_16-45-15
# 6       clef2021_beit_base_384_ce_12-03-2021_10-27-27
# 7       clef2021_vit_large_224_ce_12-03-2021_10-27-27
# 8       clef2021_vit_large_384_ce_12-07-2021_14-48-24
# 9   clef2021_deit_base_distilled_384_ce_12-22-2021...
# 10    clef2021_efficientnet_b0_ce_11-29-2021_16-52-38
#
#                                          history_file  \
# 0    clef2021_vit_base_224_ce_12-01-2021_09-37-32.csv
# 1   clef2021_efficientnet_b4_ns_ce_12-01-2021_09-3...
# 2    clef2021_vit_base_384_ce_12-01-2021_09-37-35.csv
# 3   clef2021_efficientnet_b4_ce_12-01-2021_21-42-2...
# 4   clef2021_efficientnetv2_s_ce_12-02-2021_14-00-...
# 5   clef2021_deit_base_384_ce_12-02-2021_16-45-15.csv
# 6   clef2021_beit_base_384_ce_12-03-2021_10-27-27.csv
# 7   clef2021_vit_large_224_ce_12-03-2021_10-27-27.csv
# 8   clef2021_vit_large_384_ce_12-07-2021_14-48-24.csv
# 9   clef2021_deit_base_distilled_384_ce_12-22-2021...
# 10  clef2021_efficientnet_b0_ce_11-29-2021_16-52-3...
#
#                                            specs_name  \
# 0   clef2021_vit_base_224_ce_12-01-2021_09-37-32.json
# 1   clef2021_efficientnet_b4_ns_ce_12-01-2021_09-3...
# 2   clef2021_vit_base_384_ce_12-01-2021_09-37-35.json
# 3   clef2021_efficientnet_b4_ce_12-01-2021_21-42-2...
# 4   clef2021_efficientnetv2_s_ce_12-02-2021_14-00-...
# 5   clef2021_deit_base_384_ce_12-02-2021_16-45-15....
# 6   clef2021_beit_base_384_ce_12-03-2021_10-27-27....
# 7   clef2021_vit_large_224_ce_12-03-2021_10-27-27....
# 8   clef2021_vit_large_384_ce_12-07-2021_14-48-24....
# 9   clef2021_deit_base_distilled_384_ce_12-22-2021...
# 10  clef2021_efficientnet_b0_ce_11-29-2021_16-52-3...
#
#                       model loss  opt  no_epochs  batch_size  \
# 0              vit_base_224   ce  sgd         30          64
# 1        efficientnet_b4_ns   ce  sgd         30          32
# 2              vit_base_384   ce  sgd         30          32
# 3           efficientnet_b4   ce  sgd         30          32
# 4          efficientnetv2_s   ce  sgd         30          64
# 5             deit_base_384   ce  sgd         30          32
# 6             beit_base_384   ce  sgd         30          32
# 7             vit_large_224   ce  sgd         30          64
# 8             vit_large_384   ce  sgd         30          16
# 9   deit_base_distilled_384   ce  sgd         30          32
# 10          efficientnet_b0   ce  sgd         30          64
#
#     total_batch_size  learning_rate weight       dataset  \
# 0                 64           0.01   none  full_cleaned
# 1                 64           0.01   none  full_cleaned
# 2                 64           0.01   none  full_cleaned
# 3                 64           0.01   none  full_cleaned
# 4                 64           0.01   none  full_cleaned
# 5                 64           0.01   none  full_cleaned
# 6                 64           0.01   none  full_cleaned
# 7                 64           0.01   none  full_cleaned
# 8                 64           0.01   none  full_cleaned
# 9                 64           0.01   none  full_cleaned
# 10                64           0.01   none  full_cleaned
#
#                scheduler                     pretrained_checkpoint  \
# 0   reduce_lr_on_plateau               google/vit-base-patch16-224
# 1   reduce_lr_on_plateau                     tf_efficientnet_b4_ns
# 2   reduce_lr_on_plateau               google/vit-base-patch16-384
# 3   reduce_lr_on_plateau                        tf_efficientnet_b4
# 4   reduce_lr_on_plateau                       tf_efficientnetv2_s
# 5   reduce_lr_on_plateau            facebook/deit-base-patch16-384
# 6   reduce_lr_on_plateau           microsoft/beit-base-patch16-384
# 7   reduce_lr_on_plateau              google/vit-large-patch16-224
# 8   reduce_lr_on_plateau              google/vit-large-patch16-384
# 9   reduce_lr_on_plateau  facebook/deit-base-distilled-patch16-384
# 10  reduce_lr_on_plateau                        tf_efficientnet_b0
#
#     input_size             image_mean              image_std              date
# 0          224        [0.5, 0.5, 0.5]        [0.5, 0.5, 0.5]  01-2021_09-37-32
# 1          380  [0.485, 0.456, 0.406]  [0.229, 0.224, 0.225]  01-2021_09-37-32
# 2          384        [0.5, 0.5, 0.5]        [0.5, 0.5, 0.5]  01-2021_09-37-35
# 3          380  [0.485, 0.456, 0.406]  [0.229, 0.224, 0.225]  01-2021_21-42-26
# 4          384        [0.5, 0.5, 0.5]        [0.5, 0.5, 0.5]  02-2021_14-00-43
# 5          384  [0.485, 0.456, 0.406]  [0.229, 0.224, 0.225]  02-2021_16-45-15
# 6          384        [0.5, 0.5, 0.5]        [0.5, 0.5, 0.5]  03-2021_10-27-27
# 7          224        [0.5, 0.5, 0.5]        [0.5, 0.5, 0.5]  03-2021_10-27-27
# 8          384        [0.5, 0.5, 0.5]        [0.5, 0.5, 0.5]  07-2021_14-48-24
# 9          384  [0.485, 0.456, 0.406]  [0.229, 0.224, 0.225]  22-2021_22-11-34
# 10         224  [0.485, 0.456, 0.406]  [0.229, 0.224, 0.225]  29-2021_16-52-38

# %%
params = dict(loss='ce', opt='sgd', total_batch_size=64)
group_dict = {
    'EfficientNet-B0': results.filter_items(df, outlen=30, model='efficientnet_b0', **params),
    'ViT-Base-224': results.filter_items(df, outlen=30, model='vit_base_224', **params),

    'EfficientNet-B4': results.filter_items(df, outlen=30, model='efficientnet_b4', **params),
    'NoisyStudent-B4': results.filter_items(df, outlen=30, model='efficientnet_b4_ns', **params),
    'EfficientNetV2-S': results.filter_items(df, outlen=30, model='efficientnetv2_s', **params),

    'ViT-Base-384': results.filter_items(df, outlen=30, model='vit_base_384', **params),
    'DeiT-Base-384': results.filter_items(df, outlen=30, model='deit_base_384', **params),
    'DeiT-Base-384 (distilled)': results.filter_items(df, outlen=30, model='deit_base_distilled_384', **params),
    'BEiT-Base-384': results.filter_items(df, outlen=30, model='beit_base_384', **params),

    'ViT-Large-224': results.filter_items(df, outlen=30, model='vit_large_224', **params),
    'ViT-Large-384': results.filter_items(df, outlen=30, model='vit_large_384', **params)}

result_df = results.get_metrics_and_time_df(group_dict, primary_metric='f1_score')
viz.heatmap(result_df)
result_df.round(3) * ([100] * 3 + [1, 1])
# Out:
#                            accuracy  top_3  f1_score mean_epoch_time  \
# EfficientNet-B0                85.1   94.2      70.6             24m
# ViT-Base-224                   89.9   95.6      76.0             25m
# EfficientNet-B4                91.4   96.9      80.2             57m
# NoisyStudent-B4                91.7   97.4      81.0             57m
# EfficientNetV2-S               91.6   96.0      81.3             48m
# ViT-Base-384                   91.0   97.3      81.2          1h 03m
# DeiT-Base-384                  92.0   96.9      81.3          1h 03m
# DeiT-Base-384 (distilled)      92.1   96.9      81.0          1h 02m
# BEiT-Base-384                  93.5   97.7      84.0          1h 10m
# ViT-Large-224                  87.9   96.0      77.8             46m
# ViT-Large-384                  91.9   97.7      83.0          2h 47m
#
#                           total_time
# EfficientNet-B0              11h 32m
# ViT-Base-224                 12h 04m
# EfficientNet-B4              28h 23m
# NoisyStudent-B4              28h 23m
# EfficientNetV2-S             23h 56m
# ViT-Base-384                 31h 07m
# DeiT-Base-384                31h 04m
# DeiT-Base-384 (distilled)    30h 39m
# BEiT-Base-384                34h 46m
# ViT-Large-224                22h 31m
# ViT-Large-384                83h 13m

# %%
results.compare_training_process(group_dict, xlim=[0, 30])
