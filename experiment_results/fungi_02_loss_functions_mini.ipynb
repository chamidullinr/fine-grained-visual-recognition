# %% [markdown]
# # 02 - Training Results - Loss Functions (DF20M)

# %%
import os

os.chdir('..')

# %%
from src.utils import visualization as viz
from src.dev import results

DATA_DIR = 'data/danish_fungi_dataset/training_history/loss_functions_mini/'


# load specification and progress data
specs_df = results.load_specs_files(DATA_DIR)
# specs_df['note'] = specs_df['note'].fillna('')
df = results.load_progress_files(specs_df, path=DATA_DIR)
specs_df
# Out:
#                                           model_name  \
# 0         df2020_vit_base_224_ce_11-04-2021_19-52-30
# 1      df2020_efficientnet_b0_ce_11-04-2021_19-52-55
# 2      df2020_efficientnet_b0_ce_11-22-2021_15-11-38
# 3      df2020_efficientnet_b0_ce_11-22-2021_16-16-57
# 4   df2020_efficientnet_b0_focal_11-22-2021_17-22-45
# 5   df2020_efficientnet_b0_focal_11-22-2021_18-02-40
# 6   df2020_efficientnet_b0_focal_11-22-2021_19-09-14
# 7   df2020_efficientnet_b0_focal_11-22-2021_20-14-55
# 8      df2020_efficientnet_b0_ce_11-23-2021_09-05-28
# 9      df2020_efficientnet_b0_ce_11-23-2021_10-11-49
# 10     df2020_efficientnet_b0_ce_11-23-2021_11-17-08
# 11     df2020_efficientnet_b0_ce_11-23-2021_12-21-33
# 12     df2020_efficientnet_b0_ce_11-23-2021_13-25-42
# 13        df2020_vit_base_224_ce_11-25-2021_12-41-53
# 14        df2020_vit_base_224_ce_11-25-2021_13-55-15
# 15        df2020_vit_base_224_ce_11-25-2021_15-08-03
# 16        df2020_vit_base_224_ce_11-25-2021_16-21-32
# 17        df2020_vit_base_224_ce_11-25-2021_17-34-45
# 18        df2020_vit_base_224_ce_11-25-2021_18-47-45
# 19        df2020_vit_base_224_ce_11-25-2021_20-01-01
# 20     df2020_vit_base_224_focal_11-25-2021_21-14-06
# 21     df2020_vit_base_224_focal_11-25-2021_21-43-28
# 22     df2020_vit_base_224_focal_11-25-2021_22-56-26
# 23     df2020_vit_base_224_focal_11-26-2021_00-09-28
#
#                                          history_file  \
# 0      df2020_vit_base_224_ce_11-04-2021_19-52-30.csv
# 1   df2020_efficientnet_b0_ce_11-04-2021_19-52-55.csv
# 2   df2020_efficientnet_b0_ce_11-22-2021_15-11-38.csv
# 3   df2020_efficientnet_b0_ce_11-22-2021_16-16-57.csv
# 4   df2020_efficientnet_b0_focal_11-22-2021_17-22-...
# 5   df2020_efficientnet_b0_focal_11-22-2021_18-02-...
# 6   df2020_efficientnet_b0_focal_11-22-2021_19-09-...
# 7   df2020_efficientnet_b0_focal_11-22-2021_20-14-...
# 8   df2020_efficientnet_b0_ce_11-23-2021_09-05-28.csv
# 9   df2020_efficientnet_b0_ce_11-23-2021_10-11-49.csv
# 10  df2020_efficientnet_b0_ce_11-23-2021_11-17-08.csv
# 11  df2020_efficientnet_b0_ce_11-23-2021_12-21-33.csv
# 12  df2020_efficientnet_b0_ce_11-23-2021_13-25-42.csv
# 13     df2020_vit_base_224_ce_11-25-2021_12-41-53.csv
# 14     df2020_vit_base_224_ce_11-25-2021_13-55-15.csv
# 15     df2020_vit_base_224_ce_11-25-2021_15-08-03.csv
# 16     df2020_vit_base_224_ce_11-25-2021_16-21-32.csv
# 17     df2020_vit_base_224_ce_11-25-2021_17-34-45.csv
# 18     df2020_vit_base_224_ce_11-25-2021_18-47-45.csv
# 19     df2020_vit_base_224_ce_11-25-2021_20-01-01.csv
# 20  df2020_vit_base_224_focal_11-25-2021_21-14-06.csv
# 21  df2020_vit_base_224_focal_11-25-2021_21-43-28.csv
# 22  df2020_vit_base_224_focal_11-25-2021_22-56-26.csv
# 23  df2020_vit_base_224_focal_11-26-2021_00-09-28.csv
#
#                                            specs_name            model   loss  \
# 0     df2020_vit_base_224_ce_11-04-2021_19-52-30.json     vit_base_224     ce
# 1   df2020_efficientnet_b0_ce_11-04-2021_19-52-55....  efficientnet_b0     ce
# 2   df2020_efficientnet_b0_ce_11-22-2021_15-11-38....  efficientnet_b0     ce
# 3   df2020_efficientnet_b0_ce_11-22-2021_16-16-57....  efficientnet_b0     ce
# 4   df2020_efficientnet_b0_focal_11-22-2021_17-22-...  efficientnet_b0  focal
# 5   df2020_efficientnet_b0_focal_11-22-2021_18-02-...  efficientnet_b0  focal
# 6   df2020_efficientnet_b0_focal_11-22-2021_19-09-...  efficientnet_b0  focal
# 7   df2020_efficientnet_b0_focal_11-22-2021_20-14-...  efficientnet_b0  focal
# 8   df2020_efficientnet_b0_ce_11-23-2021_09-05-28....  efficientnet_b0     ce
# 9   df2020_efficientnet_b0_ce_11-23-2021_10-11-49....  efficientnet_b0     ce
# 10  df2020_efficientnet_b0_ce_11-23-2021_11-17-08....  efficientnet_b0     ce
# 11  df2020_efficientnet_b0_ce_11-23-2021_12-21-33....  efficientnet_b0     ce
# 12  df2020_efficientnet_b0_ce_11-23-2021_13-25-42....  efficientnet_b0     ce
# 13    df2020_vit_base_224_ce_11-25-2021_12-41-53.json     vit_base_224     ce
# 14    df2020_vit_base_224_ce_11-25-2021_13-55-15.json     vit_base_224     ce
# 15    df2020_vit_base_224_ce_11-25-2021_15-08-03.json     vit_base_224     ce
# 16    df2020_vit_base_224_ce_11-25-2021_16-21-32.json     vit_base_224     ce
# 17    df2020_vit_base_224_ce_11-25-2021_17-34-45.json     vit_base_224     ce
# 18    df2020_vit_base_224_ce_11-25-2021_18-47-45.json     vit_base_224     ce
# 19    df2020_vit_base_224_ce_11-25-2021_20-01-01.json     vit_base_224     ce
# 20  df2020_vit_base_224_focal_11-25-2021_21-14-06....     vit_base_224  focal
# 21  df2020_vit_base_224_focal_11-25-2021_21-43-28....     vit_base_224  focal
# 22  df2020_vit_base_224_focal_11-25-2021_22-56-26....     vit_base_224  focal
# 23  df2020_vit_base_224_focal_11-26-2021_00-09-28....     vit_base_224  focal
#
#     opt  no_epochs  batch_size  total_batch_size  learning_rate  \
# 0   sgd         30          64                64           0.01
# 1   sgd         30          64                64           0.01
# 2   sgd         30          64                64           0.01
# 3   sgd         30          64                64           0.01
# 4   sgd         30          64                64           0.01
# 5   sgd         30          64                64           0.01
# 6   sgd         30          64                64           0.01
# 7   sgd         30          64                64           0.01
# 8   sgd         30          64                64           0.01
# 9   sgd         30          64                64           0.01
# 10  sgd         30          64                64           0.01
# 11  sgd         30          64                64           0.01
# 12  sgd         30          64                64           0.01
# 13  sgd         30          64                64           0.01
# 14  sgd         30          64                64           0.01
# 15  sgd         30          64                64           0.01
# 16  sgd         30          64                64           0.01
# 17  sgd         30          64                64           0.01
# 18  sgd         30          64                64           0.01
# 19  sgd         30          64                64           0.01
# 20  sgd         30          64                64           0.01
# 21  sgd         30          64                64           0.01
# 22  sgd         30          64                64           0.01
# 23  sgd         30          64                64           0.01
#
#                      weight dataset             scheduler  \
# 0                      none    mini  reduce_lr_on_plateau
# 1                      none    mini  reduce_lr_on_plateau
# 2   inverse_class_frequency    mini  reduce_lr_on_plateau
# 3              linear_class    mini  reduce_lr_on_plateau
# 4                      none    mini  reduce_lr_on_plateau
# 5                      none    mini  reduce_lr_on_plateau
# 6                      none    mini  reduce_lr_on_plateau
# 7                      none    mini  reduce_lr_on_plateau
# 8     modified_linear_class    mini  reduce_lr_on_plateau
# 9            class_balanced    mini  reduce_lr_on_plateau
# 10           class_balanced    mini  reduce_lr_on_plateau
# 11           class_balanced    mini  reduce_lr_on_plateau
# 12           class_balanced    mini  reduce_lr_on_plateau
# 13  inverse_class_frequency    mini  reduce_lr_on_plateau
# 14             linear_class    mini  reduce_lr_on_plateau
# 15    modified_linear_class    mini  reduce_lr_on_plateau
# 16           class_balanced    mini  reduce_lr_on_plateau
# 17           class_balanced    mini  reduce_lr_on_plateau
# 18           class_balanced    mini  reduce_lr_on_plateau
# 19           class_balanced    mini  reduce_lr_on_plateau
# 20                     none    mini  reduce_lr_on_plateau
# 21                     none    mini  reduce_lr_on_plateau
# 22                     none    mini  reduce_lr_on_plateau
# 23                     none    mini  reduce_lr_on_plateau
#
#           pretrained_checkpoint  input_size             image_mean  \
# 0   google/vit-base-patch16-224         224        [0.5, 0.5, 0.5]
# 1            tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 2            tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 3            tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 4            tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 5            tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 6            tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 7            tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 8            tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 9            tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 10           tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 11           tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 12           tf_efficientnet_b0         224  [0.485, 0.456, 0.406]
# 13  google/vit-base-patch16-224         224        [0.5, 0.5, 0.5]
# 14  google/vit-base-patch16-224         224        [0.5, 0.5, 0.5]
# 15  google/vit-base-patch16-224         224        [0.5, 0.5, 0.5]
# 16  google/vit-base-patch16-224         224        [0.5, 0.5, 0.5]
# 17  google/vit-base-patch16-224         224        [0.5, 0.5, 0.5]
# 18  google/vit-base-patch16-224         224        [0.5, 0.5, 0.5]
# 19  google/vit-base-patch16-224         224        [0.5, 0.5, 0.5]
# 20  google/vit-base-patch16-224         224        [0.5, 0.5, 0.5]
# 21  google/vit-base-patch16-224         224        [0.5, 0.5, 0.5]
# 22  google/vit-base-patch16-224         224        [0.5, 0.5, 0.5]
# 23  google/vit-base-patch16-224         224        [0.5, 0.5, 0.5]
#
#                 image_std    beta  gamma              date
# 0         [0.5, 0.5, 0.5]     NaN    NaN  04-2021_19-52-30
# 1   [0.229, 0.224, 0.225]     NaN    NaN  04-2021_19-52-55
# 2   [0.229, 0.224, 0.225]     NaN    NaN  22-2021_15-11-38
# 3   [0.229, 0.224, 0.225]     NaN    NaN  22-2021_16-16-57
# 4   [0.229, 0.224, 0.225]     NaN    0.5  22-2021_17-22-45
# 5   [0.229, 0.224, 0.225]     NaN    1.0  22-2021_18-02-40
# 6   [0.229, 0.224, 0.225]     NaN    2.0  22-2021_19-09-14
# 7   [0.229, 0.224, 0.225]     NaN    5.0  22-2021_20-14-55
# 8   [0.229, 0.224, 0.225]     NaN    NaN  23-2021_09-05-28
# 9   [0.229, 0.224, 0.225]  0.9000    NaN  23-2021_10-11-49
# 10  [0.229, 0.224, 0.225]  0.9900    NaN  23-2021_11-17-08
# 11  [0.229, 0.224, 0.225]  0.9990    NaN  23-2021_12-21-33
# 12  [0.229, 0.224, 0.225]  0.9999    NaN  23-2021_13-25-42
# 13        [0.5, 0.5, 0.5]     NaN    NaN  25-2021_12-41-53
# 14        [0.5, 0.5, 0.5]     NaN    NaN  25-2021_13-55-15
# 15        [0.5, 0.5, 0.5]     NaN    NaN  25-2021_15-08-03
# 16        [0.5, 0.5, 0.5]  0.9000    NaN  25-2021_16-21-32
# 17        [0.5, 0.5, 0.5]  0.9900    NaN  25-2021_17-34-45
# 18        [0.5, 0.5, 0.5]  0.9990    NaN  25-2021_18-47-45
# 19        [0.5, 0.5, 0.5]  0.9999    NaN  25-2021_20-01-01
# 20        [0.5, 0.5, 0.5]     NaN    0.5  25-2021_21-14-06
# 21        [0.5, 0.5, 0.5]     NaN    1.0  25-2021_21-43-28
# 22        [0.5, 0.5, 0.5]     NaN    2.0  25-2021_22-56-26
# 23        [0.5, 0.5, 0.5]     NaN    5.0  26-2021_00-09-28

# %% [markdown]
# ## EfficientNet-B0

# %%
params = dict(model='efficientnet_b0', total_batch_size=64)
group_dict = {
    'CE': results.filter_items(df, outlen=30, loss='ce', weight='none', **params),
    'CE - Inverse Class Frequency': results.filter_items(df, outlen=30, loss='ce', weight='inverse_class_frequency', **params),
    'CE - Linear Class': results.filter_items(df, outlen=30, loss='ce', weight='linear_class', **params),
    'CE - Modified Linear Class': results.filter_items(df, outlen=30, loss='ce', weight='modified_linear_class', **params),
    'CE - Class Balanced (beta=0.9)': results.filter_items(df, outlen=30, loss='ce', weight='class_balanced', beta=0.9, **params),
    'CE - Class Balanced (beta=0.99)': results.filter_items(df, outlen=30, loss='ce', weight='class_balanced', beta=0.99, **params),
    'CE - Class Balanced (beta=0.999)': results.filter_items(df, outlen=30, loss='ce', weight='class_balanced', beta=0.999, **params),
    'CE - Class Balanced (beta=0.9999)': results.filter_items(df, outlen=30, loss='ce', weight='class_balanced', beta=0.9999, **params),
    'FL (gamma=0.5)': results.filter_items(df, outlen=None, loss='focal', weight='none', gamma=0.5, **params),
    'FL (gamma=1.0)': results.filter_items(df, outlen=30, loss='focal', weight='none', gamma=1.0, **params),
    'FL (gamma=2.0)': results.filter_items(df, outlen=30, loss='focal', weight='none', gamma=2.0, **params),
    'FL (gamma=5.0)': results.filter_items(df, outlen=30, loss='focal', weight='none', gamma=5.0, **params)}

result_df = results.get_metrics_and_time_df(group_dict, primary_metric='f1_score')
viz.heatmap(result_df)
result_df.round(3) * ([100] * 3 + [1, 1])
# Out:
#                                    accuracy  top_3  f1_score mean_epoch_time  \
# CE                                     63.1   81.0      51.8             03m
# CE - Inverse Class Frequency           62.3   80.9      51.5             03m
# CE - Linear Class                      62.3   80.9      51.4             03m
# CE - Modified Linear Class             63.3   81.6      52.5             03m
# CE - Class Balanced (beta=0.9)         62.8   81.4      51.2             03m
# CE - Class Balanced (beta=0.99)        62.8   81.5      51.9             03m
# CE - Class Balanced (beta=0.999)       62.0   81.2      51.4             03m
# CE - Class Balanced (beta=0.9999)      63.2   81.2      52.8             03m
# FL (gamma=0.5)                         62.1   80.9      50.4             03m
# FL (gamma=1.0)                         62.3   81.4      50.8             03m
# FL (gamma=2.0)                         62.3   81.6      51.0             03m
# FL (gamma=5.0)                         62.3   81.8      51.1             03m
#
#                                   total_time
# CE                                    1h 05m
# CE - Inverse Class Frequency          1h 06m
# CE - Linear Class                     1h 06m
# CE - Modified Linear Class            1h 07m
# CE - Class Balanced (beta=0.9)        1h 05m
# CE - Class Balanced (beta=0.99)       1h 05m
# CE - Class Balanced (beta=0.999)      1h 04m
# CE - Class Balanced (beta=0.9999)     1h 04m
# FL (gamma=0.5)                           38m
# FL (gamma=1.0)                        1h 07m
# FL (gamma=2.0)                        1h 06m
# FL (gamma=5.0)                        1h 07m

# %%
print(f'FL (gamma=0.5) trained only for: {len(group_dict["FL (gamma=0.5)"])}')
# Out:
# FL (gamma=0.5) trained only for: 17

# %%
_result_df = result_df[['accuracy', 'top_3', 'f1_score']]
(_result_df - _result_df.loc['CE']).round(3) * 100
# Out:
#                                    accuracy  top_3  f1_score
# CE                                      0.0    0.0       0.0
# CE - Inverse Class Frequency           -0.8   -0.1      -0.3
# CE - Linear Class                      -0.7   -0.1      -0.4
# CE - Modified Linear Class              0.2    0.5       0.7
# CE - Class Balanced (beta=0.9)         -0.3    0.4      -0.6
# CE - Class Balanced (beta=0.99)        -0.2    0.5       0.1
# CE - Class Balanced (beta=0.999)       -1.0    0.1      -0.4
# CE - Class Balanced (beta=0.9999)       0.1    0.2       1.0
# FL (gamma=0.5)                         -1.0   -0.1      -1.4
# FL (gamma=1.0)                         -0.8    0.4      -1.0
# FL (gamma=2.0)                         -0.8    0.5      -0.8
# FL (gamma=5.0)                         -0.8    0.8      -0.7

# %%
# results.compare_training_process(group_dict)

# %% [markdown]
# ## ViT-Base-224

# %%
params = dict(model='vit_base_224', total_batch_size=64)
group_dict = {
    'CE': results.filter_items(df, outlen=30, loss='ce', weight='none', **params),
    'CE - Inverse Class Frequency': results.filter_items(df, outlen=30, loss='ce', weight='inverse_class_frequency', **params),
    'CE - Linear Class': results.filter_items(df, outlen=30, loss='ce', weight='linear_class', **params),
    'CE - Modified Linear Class': results.filter_items(df, outlen=30, loss='ce', weight='modified_linear_class', **params),
    'CE - Class Balanced (beta=0.9)': results.filter_items(df, outlen=30, loss='ce', weight='class_balanced', beta=0.9, **params),
    'CE - Class Balanced (beta=0.99)': results.filter_items(df, outlen=30, loss='ce', weight='class_balanced', beta=0.99, **params),
    'CE - Class Balanced (beta=0.999)': results.filter_items(df, outlen=30, loss='ce', weight='class_balanced', beta=0.999, **params),
    'CE - Class Balanced (beta=0.9999)': results.filter_items(df, outlen=30, loss='ce', weight='class_balanced', beta=0.9999, **params),
    'FL (gamma=0.5)': results.filter_items(df, outlen=None, loss='focal', weight='none', gamma=0.5, **params),
    'FL (gamma=1.0)': results.filter_items(df, outlen=30, loss='focal', weight='none', gamma=1.0, **params),
    'FL (gamma=2.0)': results.filter_items(df, outlen=30, loss='focal', weight='none', gamma=2.0, **params),
    'FL (gamma=5.0)': results.filter_items(df, outlen=30, loss='focal', weight='none', gamma=5.0, **params)}

result_df = results.get_metrics_and_time_df(group_dict, primary_metric='f1_score')
viz.heatmap(result_df)
result_df.round(3) * ([100] * 3 + [1, 1])
# Out:
#                                    accuracy  top_3  f1_score mean_epoch_time  \
# CE                                     68.5   85.4      58.6             03m
# CE - Inverse Class Frequency           68.0   84.8      57.8             03m
# CE - Linear Class                      67.9   84.7      57.8             03m
# CE - Modified Linear Class             69.1   86.1      58.0             03m
# CE - Class Balanced (beta=0.9)         69.0   85.7      58.0             03m
# CE - Class Balanced (beta=0.99)        68.8   86.1      58.2             03m
# CE - Class Balanced (beta=0.999)       68.3   84.9      58.4             03m
# CE - Class Balanced (beta=0.9999)      68.1   85.4      59.3             03m
# FL (gamma=0.5)                         67.3   84.5      55.7             03m
# FL (gamma=1.0)                         69.0   85.7      57.6             03m
# FL (gamma=2.0)                         68.2   86.2      57.4             03m
# FL (gamma=5.0)                         68.0   85.9      56.5             03m
#
#                                   total_time
# CE                                    1h 12m
# CE - Inverse Class Frequency          1h 13m
# CE - Linear Class                     1h 13m
# CE - Modified Linear Class            1h 13m
# CE - Class Balanced (beta=0.9)        1h 13m
# CE - Class Balanced (beta=0.99)       1h 13m
# CE - Class Balanced (beta=0.999)      1h 13m
# CE - Class Balanced (beta=0.9999)     1h 13m
# FL (gamma=0.5)                           27m
# FL (gamma=1.0)                        1h 13m
# FL (gamma=2.0)                        1h 13m
# FL (gamma=5.0)                        1h 13m

# %%
print(f'FL (gamma=0.5) trained only for: {len(group_dict["FL (gamma=0.5)"])}')
# Out:
# FL (gamma=0.5) trained only for: 11

# %%
_result_df = result_df[['accuracy', 'top_3', 'f1_score']]
(_result_df - _result_df.loc['CE']).round(3) * 100
# Out:
#                                    accuracy  top_3  f1_score
# CE                                      0.0    0.0       0.0
# CE - Inverse Class Frequency           -0.5   -0.6      -0.8
# CE - Linear Class                      -0.6   -0.7      -0.8
# CE - Modified Linear Class              0.5    0.7      -0.6
# CE - Class Balanced (beta=0.9)          0.5    0.3      -0.6
# CE - Class Balanced (beta=0.99)         0.2    0.7      -0.4
# CE - Class Balanced (beta=0.999)       -0.2   -0.5      -0.2
# CE - Class Balanced (beta=0.9999)      -0.4    0.0       0.7
# FL (gamma=0.5)                         -1.3   -0.9      -2.9
# FL (gamma=1.0)                          0.4    0.4      -1.0
# FL (gamma=2.0)                         -0.3    0.8      -1.2
# FL (gamma=5.0)                         -0.5    0.6      -2.1

# %%
# results.compare_training_process(group_dict)
