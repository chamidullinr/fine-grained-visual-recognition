# %% [markdown]
# # 01 - Training Results - Baseline Networks (DF20)

# %%
import os

os.chdir('..')

# %%
from src.utils import visualization as viz
from src.dev import results

DATA_DIR = 'data/danish_fungi_dataset/training_history/baselines/'


# load specification and progress data
specs_df = results.load_specs_files(DATA_DIR)
df = results.load_progress_files(specs_df, path=DATA_DIR)
specs_df
# Out:
#                                            model_name  \
# 0         df2020_beit_base_384_ce_12-01-2021_09-35-05
# 1         df2020_vit_large_384_ce_12-01-2021_09-35-07
# 2         df2020_vit_large_224_ce_12-02-2021_11-08-10
# 3   df2020_deit_base_distilled_384_ce_12-22-2021_1...
# 4       df2020_efficientnet_b0_ce_11-28-2021_11-38-24
# 5          df2020_vit_base_224_ce_11-29-2021_14-26-24
# 6    df2020_efficientnet_b4_ns_ce_11-29-2021_14-26-25
# 7          df2020_vit_base_384_ce_11-29-2021_15-53-09
# 8       df2020_efficientnet_b4_ce_11-29-2021_23-53-44
# 9      df2020_efficientnetv2_s_ce_11-30-2021_11-09-39
# 10        df2020_deit_base_384_ce_11-30-2021_13-59-27
#
#                                          history_file  \
# 0     df2020_beit_base_384_ce_12-01-2021_09-35-05.csv
# 1     df2020_vit_large_384_ce_12-01-2021_09-35-07.csv
# 2     df2020_vit_large_224_ce_12-02-2021_11-08-10.csv
# 3   df2020_deit_base_distilled_384_ce_12-22-2021_1...
# 4   df2020_efficientnet_b0_ce_11-28-2021_11-38-24.csv
# 5      df2020_vit_base_224_ce_11-29-2021_14-26-24.csv
# 6   df2020_efficientnet_b4_ns_ce_11-29-2021_14-26-...
# 7      df2020_vit_base_384_ce_11-29-2021_15-53-09.csv
# 8   df2020_efficientnet_b4_ce_11-29-2021_23-53-44.csv
# 9   df2020_efficientnetv2_s_ce_11-30-2021_11-09-39...
# 10    df2020_deit_base_384_ce_11-30-2021_13-59-27.csv
#
#                                            specs_name  \
# 0    df2020_beit_base_384_ce_12-01-2021_09-35-05.json
# 1    df2020_vit_large_384_ce_12-01-2021_09-35-07.json
# 2    df2020_vit_large_224_ce_12-02-2021_11-08-10.json
# 3   df2020_deit_base_distilled_384_ce_12-22-2021_1...
# 4   df2020_efficientnet_b0_ce_11-28-2021_11-38-24....
# 5     df2020_vit_base_224_ce_11-29-2021_14-26-24.json
# 6   df2020_efficientnet_b4_ns_ce_11-29-2021_14-26-...
# 7     df2020_vit_base_384_ce_11-29-2021_15-53-09.json
# 8   df2020_efficientnet_b4_ce_11-29-2021_23-53-44....
# 9   df2020_efficientnetv2_s_ce_11-30-2021_11-09-39...
# 10   df2020_deit_base_384_ce_11-30-2021_13-59-27.json
#
#                       model loss  opt  no_epochs  batch_size  \
# 0             beit_base_384   ce  sgd         30          32
# 1             vit_large_384   ce  sgd         30          16
# 2             vit_large_224   ce  sgd         30          64
# 3   deit_base_distilled_384   ce  sgd         30          32
# 4           efficientnet_b0   ce  sgd         30          64
# 5              vit_base_224   ce  sgd         30          64
# 6        efficientnet_b4_ns   ce  sgd         30          32
# 7              vit_base_384   ce  sgd         30          32
# 8           efficientnet_b4   ce  sgd         30          32
# 9          efficientnetv2_s   ce  sgd         30          64
# 10            deit_base_384   ce  sgd         30          32
#
#     total_batch_size  learning_rate weight dataset             scheduler  \
# 0                 64           0.01   none    full  reduce_lr_on_plateau
# 1                 64           0.01   none    full  reduce_lr_on_plateau
# 2                 64           0.01   none    full  reduce_lr_on_plateau
# 3                 64           0.01   none    full  reduce_lr_on_plateau
# 4                 64           0.01   none    full  reduce_lr_on_plateau
# 5                 64           0.01   none    full  reduce_lr_on_plateau
# 6                 64           0.01   none    full  reduce_lr_on_plateau
# 7                 64           0.01   none    full  reduce_lr_on_plateau
# 8                 64           0.01   none    full  reduce_lr_on_plateau
# 9                 64           0.01   none    full  reduce_lr_on_plateau
# 10                64           0.01   none    full  reduce_lr_on_plateau
#
#                        pretrained_checkpoint  input_size  \
# 0            microsoft/beit-base-patch16-384         384
# 1               google/vit-large-patch16-384         384
# 2               google/vit-large-patch16-224         224
# 3   facebook/deit-base-distilled-patch16-384         384
# 4                         tf_efficientnet_b0         224
# 5                google/vit-base-patch16-224         224
# 6                      tf_efficientnet_b4_ns         380
# 7                google/vit-base-patch16-384         384
# 8                         tf_efficientnet_b4         380
# 9                        tf_efficientnetv2_s         384
# 10            facebook/deit-base-patch16-384         384
#
#                image_mean              image_std              date
# 0         [0.5, 0.5, 0.5]        [0.5, 0.5, 0.5]  01-2021_09-35-05
# 1         [0.5, 0.5, 0.5]        [0.5, 0.5, 0.5]  01-2021_09-35-07
# 2         [0.5, 0.5, 0.5]        [0.5, 0.5, 0.5]  02-2021_11-08-10
# 3   [0.485, 0.456, 0.406]  [0.229, 0.224, 0.225]  22-2021_18-12-17
# 4   [0.485, 0.456, 0.406]  [0.229, 0.224, 0.225]  28-2021_11-38-24
# 5         [0.5, 0.5, 0.5]        [0.5, 0.5, 0.5]  29-2021_14-26-24
# 6   [0.485, 0.456, 0.406]  [0.229, 0.224, 0.225]  29-2021_14-26-25
# 7         [0.5, 0.5, 0.5]        [0.5, 0.5, 0.5]  29-2021_15-53-09
# 8   [0.485, 0.456, 0.406]  [0.229, 0.224, 0.225]  29-2021_23-53-44
# 9         [0.5, 0.5, 0.5]        [0.5, 0.5, 0.5]  30-2021_11-09-39
# 10  [0.485, 0.456, 0.406]  [0.229, 0.224, 0.225]  30-2021_13-59-27

# %%
params = dict(loss='ce', opt='sgd', total_batch_size=64)
group_dict = {
    'EfficientNet-B0': results.filter_items(df, outlen=30, model='efficientnet_b0', **params),
    'ViT-Base-224': results.filter_items(df, outlen=30, model='vit_base_224', **params),

    'EfficientNet-B4': results.filter_items(df, outlen=30, model='efficientnet_b4', **params),
    'NoisyStudent-B4': results.filter_items(df, outlen=30, model='efficientnet_b4_ns', **params),
    'EfficientNetV2-S': results.filter_items(df, outlen=30, model='efficientnetv2_s', **params),

    'ViT-Base-384': results.filter_items(df, outlen=30, model='vit_base_384', **params),
    'DeiT-Base-384': results.filter_items(df, outlen=30, model='deit_base_384', **params),
    'DeiT-Base-384 (distilled)': results.filter_items(df, outlen=30, model='deit_base_distilled_384', **params),
    'BEiT-Base-384': results.filter_items(df, outlen=30, model='beit_base_384', **params),

    'ViT-Large-224': results.filter_items(df, outlen=30, model='vit_large_224', **params),
    'ViT-Large-384': results.filter_items(df, outlen=30, model='vit_large_384', **params)}

result_df = results.get_metrics_and_time_df(group_dict, primary_metric='f1_score')
viz.heatmap(result_df)
result_df.round(3) * ([100] * 3 + [1, 1])
# Out:
#                            accuracy  top_3  f1_score mean_epoch_time  \
# EfficientNet-B0                67.7   83.3      58.2             19m
# ViT-Base-224                   73.4   87.0      66.0             19m
# EfficientNet-B4                74.8   88.2      66.1             42m
# NoisyStudent-B4                76.3   89.0      68.1             42m
# EfficientNetV2-S               76.7   89.2      68.0             35m
# ViT-Base-384                   78.7   90.5      71.7             45m
# DeiT-Base-384                  78.0   89.9      70.9             45m
# DeiT-Base-384 (distilled)      77.5   89.6      70.2             45m
# BEiT-Base-384                  77.1   89.6      69.5             52m
# ViT-Large-224                  74.9   88.0      67.3             34m
# ViT-Large-384                  80.6   91.8      74.5          2h 00m
#
#                           total_time
# EfficientNet-B0               9h 28m
# ViT-Base-224                  9h 26m
# EfficientNet-B4              20h 51m
# NoisyStudent-B4              20h 42m
# EfficientNetV2-S             17h 27m
# ViT-Base-384                 22h 05m
# DeiT-Base-384                22h 04m
# DeiT-Base-384 (distilled)    22h 20m
# BEiT-Base-384                25h 31m
# ViT-Large-224                16h 33m
# ViT-Large-384                59h 53m

# %%
results.compare_training_process(group_dict, xlim=[0, 30])
