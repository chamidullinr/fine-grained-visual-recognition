# %% [markdown]
# # 01 - Training Results - Baseline Networks (DF20M)

# %%
import os

os.chdir('..')

# %%
from src.utils import visualization as viz
from src.dev import results

DATA_DIR = 'data/danish_fungi_dataset/training_history/baselines_mini/'


# load specification and progress data
specs_df = results.load_specs_files(DATA_DIR)
df = results.load_progress_files(specs_df, path=DATA_DIR)
specs_df
# Out:
#                                            model_name  \
# 0          df2020_vit_base_224_ce_11-04-2021_19-52-30
# 1       df2020_efficientnet_b0_ce_11-04-2021_19-52-55
# 2         df2020_vit_large_224_ce_11-04-2021_19-52-58
# 3   df2020_deit_base_distilled_384_ce_12-22-2021_1...
# 4       df2020_efficientnet_b4_ce_11-23-2021_15-20-52
# 5    df2020_efficientnet_b4_ns_ce_11-23-2021_17-54-24
# 6      df2020_efficientnetv2_s_ce_11-23-2021_20-27-25
# 7          df2020_vit_base_384_ce_11-23-2021_22-36-27
# 8         df2020_deit_base_384_ce_11-24-2021_01-21-59
# 9         df2020_beit_base_384_ce_11-24-2021_04-07-33
# 10        df2020_vit_large_384_ce_11-26-2021_04-19-52
#
#                                          history_file  \
# 0      df2020_vit_base_224_ce_11-04-2021_19-52-30.csv
# 1   df2020_efficientnet_b0_ce_11-04-2021_19-52-55.csv
# 2     df2020_vit_large_224_ce_11-04-2021_19-52-58.csv
# 3   df2020_deit_base_distilled_384_ce_12-22-2021_1...
# 4   df2020_efficientnet_b4_ce_11-23-2021_15-20-52.csv
# 5   df2020_efficientnet_b4_ns_ce_11-23-2021_17-54-...
# 6   df2020_efficientnetv2_s_ce_11-23-2021_20-27-25...
# 7      df2020_vit_base_384_ce_11-23-2021_22-36-27.csv
# 8     df2020_deit_base_384_ce_11-24-2021_01-21-59.csv
# 9     df2020_beit_base_384_ce_11-24-2021_04-07-33.csv
# 10    df2020_vit_large_384_ce_11-26-2021_04-19-52.csv
#
#                                            specs_name  \
# 0     df2020_vit_base_224_ce_11-04-2021_19-52-30.json
# 1   df2020_efficientnet_b0_ce_11-04-2021_19-52-55....
# 2    df2020_vit_large_224_ce_11-04-2021_19-52-58.json
# 3   df2020_deit_base_distilled_384_ce_12-22-2021_1...
# 4   df2020_efficientnet_b4_ce_11-23-2021_15-20-52....
# 5   df2020_efficientnet_b4_ns_ce_11-23-2021_17-54-...
# 6   df2020_efficientnetv2_s_ce_11-23-2021_20-27-25...
# 7     df2020_vit_base_384_ce_11-23-2021_22-36-27.json
# 8    df2020_deit_base_384_ce_11-24-2021_01-21-59.json
# 9    df2020_beit_base_384_ce_11-24-2021_04-07-33.json
# 10   df2020_vit_large_384_ce_11-26-2021_04-19-52.json
#
#                       model loss  opt  no_epochs  batch_size  \
# 0              vit_base_224   ce  sgd         30          64
# 1           efficientnet_b0   ce  sgd         30          64
# 2             vit_large_224   ce  sgd         30          64
# 3   deit_base_distilled_384   ce  sgd         30          32
# 4           efficientnet_b4   ce  sgd         30          32
# 5        efficientnet_b4_ns   ce  sgd         30          32
# 6          efficientnetv2_s   ce  sgd         30          64
# 7              vit_base_384   ce  sgd         30          32
# 8             deit_base_384   ce  sgd         30          32
# 9             beit_base_384   ce  sgd         30          32
# 10            vit_large_384   ce  sgd         30          16
#
#     total_batch_size  learning_rate weight dataset             scheduler  \
# 0                 64           0.01   none    mini  reduce_lr_on_plateau
# 1                 64           0.01   none    mini  reduce_lr_on_plateau
# 2                 64           0.01   none    mini  reduce_lr_on_plateau
# 3                 64           0.01   none    mini  reduce_lr_on_plateau
# 4                 64           0.01   none    mini  reduce_lr_on_plateau
# 5                 64           0.01   none    mini  reduce_lr_on_plateau
# 6                 64           0.01   none    mini  reduce_lr_on_plateau
# 7                 64           0.01   none    mini  reduce_lr_on_plateau
# 8                 64           0.01   none    mini  reduce_lr_on_plateau
# 9                 64           0.01   none    mini  reduce_lr_on_plateau
# 10                64           0.01   none    mini  reduce_lr_on_plateau
#
#                        pretrained_checkpoint  input_size  \
# 0                google/vit-base-patch16-224         224
# 1                         tf_efficientnet_b0         224
# 2               google/vit-large-patch16-224         224
# 3   facebook/deit-base-distilled-patch16-384         384
# 4                         tf_efficientnet_b4         380
# 5                      tf_efficientnet_b4_ns         380
# 6                        tf_efficientnetv2_s         384
# 7                google/vit-base-patch16-384         384
# 8             facebook/deit-base-patch16-384         384
# 9            microsoft/beit-base-patch16-384         384
# 10              google/vit-large-patch16-384         384
#
#                image_mean              image_std              date
# 0         [0.5, 0.5, 0.5]        [0.5, 0.5, 0.5]  04-2021_19-52-30
# 1   [0.485, 0.456, 0.406]  [0.229, 0.224, 0.225]  04-2021_19-52-55
# 2         [0.5, 0.5, 0.5]        [0.5, 0.5, 0.5]  04-2021_19-52-58
# 3   [0.485, 0.456, 0.406]  [0.229, 0.224, 0.225]  22-2021_15-27-08
# 4   [0.485, 0.456, 0.406]  [0.229, 0.224, 0.225]  23-2021_15-20-52
# 5   [0.485, 0.456, 0.406]  [0.229, 0.224, 0.225]  23-2021_17-54-24
# 6         [0.5, 0.5, 0.5]        [0.5, 0.5, 0.5]  23-2021_20-27-25
# 7         [0.5, 0.5, 0.5]        [0.5, 0.5, 0.5]  23-2021_22-36-27
# 8   [0.485, 0.456, 0.406]  [0.229, 0.224, 0.225]  24-2021_01-21-59
# 9         [0.5, 0.5, 0.5]        [0.5, 0.5, 0.5]  24-2021_04-07-33
# 10        [0.5, 0.5, 0.5]        [0.5, 0.5, 0.5]  26-2021_04-19-52

# %%
params = dict(loss='ce', opt='sgd', total_batch_size=64)
group_dict = {
    'EfficientNet-B0': results.filter_items(df, outlen=30, model='efficientnet_b0', **params),
    'ViT-Base-224': results.filter_items(df, outlen=30, model='vit_base_224', **params),

    'EfficientNet-B4': results.filter_items(df, outlen=30, model='efficientnet_b4', **params),
    'NoisyStudent-B4': results.filter_items(df, outlen=30, model='efficientnet_b4_ns', **params),
    'EfficientNetV2-S': results.filter_items(df, outlen=30, model='efficientnetv2_s', **params),

    'ViT-Base-384': results.filter_items(df, outlen=30, model='vit_base_384', **params),
    'DeiT-Base-384': results.filter_items(df, outlen=30, model='deit_base_384', **params),
    'DeiT-Base-384 (distilled)': results.filter_items(df, outlen=30, model='deit_base_distilled_384', **params),
    'BEiT-Base-384': results.filter_items(df, outlen=30, model='beit_base_384', **params),

    'ViT-Large-224': results.filter_items(df, outlen=30, model='vit_large_224', **params),
    'ViT-Large-384': results.filter_items(df, outlen=30, model='vit_large_384', **params)}

result_df = results.get_metrics_and_time_df(group_dict, primary_metric='f1_score')
viz.heatmap(result_df)
result_df.round(3) * ([100] * 3 + [1, 1])
# Out:
#                            accuracy  top_3  f1_score mean_epoch_time  \
# EfficientNet-B0                63.1   81.0      51.8             03m
# ViT-Base-224                   68.5   85.4      58.6             03m
# EfficientNet-B4                68.4   85.1      58.2             06m
# NoisyStudent-B4                70.2   86.1      59.7             06m
# EfficientNetV2-S               70.0   85.6      59.4             05m
# ViT-Base-384                   74.7   88.5      65.7             06m
# DeiT-Base-384                  73.0   87.6      63.4             06m
# DeiT-Base-384 (distilled)      71.7   87.0      61.8             06m
# BEiT-Base-384                  73.2   88.1      64.3             07m
# ViT-Large-224                  70.8   86.1      60.9             05m
# ViT-Large-384                  75.5   89.3      66.1             15m
#
#                           total_time
# EfficientNet-B0               1h 05m
# ViT-Base-224                  1h 12m
# EfficientNet-B4               2h 34m
# NoisyStudent-B4               2h 33m
# EfficientNetV2-S              2h 09m
# ViT-Base-384                  2h 45m
# DeiT-Base-384                 2h 45m
# DeiT-Base-384 (distilled)     2h 45m
# BEiT-Base-384                 3h 07m
# ViT-Large-224                 2h 03m
# ViT-Large-384                 7h 26m

# %%
results.compare_training_process(group_dict, xlim=[0, 30])
